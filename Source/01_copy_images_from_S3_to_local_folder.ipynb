# %%
import os

# %%
os.getcwd()
# Out:
# '/home/ec2-user/SageMaker/DAAN 570/Lesson VIII'

# %%
os.getcwd()
# Out:
# '/home/ec2-user/SageMaker/DAAN 570/Lesson VIII'

# %%
# !aws s3 cp s3://daan570/images/images/ images/ --recursive
# Out:
# download: s3://daan570/images/images/cats/cats_00003.jpg to images/cats/cats_00003.jpg
# download: s3://daan570/images/images/cats/cats_00007.jpg to images/cats/cats_00007.jpg
# download: s3://daan570/images/images/cats/cats_00004.jpg to images/cats/cats_00004.jpg
# download: s3://daan570/images/images/cats/cats_00001.jpg to images/cats/cats_00001.jpg
# download: s3://daan570/images/images/cats/cats_00002.jpg to images/cats/cats_00002.jpg
# download: s3://daan570/images/images/cats/cats_00005.jpg to images/cats/cats_00005.jpg
# download: s3://daan570/images/images/cats/cats_00011.jpg to images/cats/cats_00011.jpg
# download: s3://daan570/images/images/cats/cats_00012.jpg to images/cats/cats_00012.jpg
# download: s3://daan570/images/images/cats/cats_00006.jpg to images/cats/cats_00006.jpg
# download: s3://daan570/images/images/cats/cats_00010.jpg to images/cats/cats_00010.jpg
# download: s3://daan570/images/images/cats/cats_00009.jpg to images/cats/cats_00009.jpg
# ...
